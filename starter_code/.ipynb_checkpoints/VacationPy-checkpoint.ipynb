# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0            wanning  18.8003  110.3967     31.60        60
# 1        1  port-aux-francais -49.3500   70.2167      3.38        84
# 2        2           pimentel  -6.8367  -79.9342     23.16        73
# 3        3             bethel  41.3712  -73.4140     24.20        73
# 4        4               kone -21.0595  164.8658     19.85        59
#
#    Cloudiness  Wind Speed Country        Date
# 0          72        5.23      CN  1691632765
# 1         100       10.57      TF  1691633047
# 2          75        6.17      PE  1691632674
# 3           0        3.60      US  1691633047
# 4          83        6.75      NC  1691632726

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_map = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = 'Humidity',
    color = 'City'
)

# Display the map
city_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
filtered_cities = city_data_df[(city_data_df['Max Temp'] > 21) & (city_data_df['Max Temp'] < 27)]
filtered_cities = filtered_cities[filtered_cities['Wind Speed'] < 4.5]
filtered_cities = filtered_cities[filtered_cities['Cloudiness'] == 0]

# Drop any rows with null values
filtered_cities = filtered_cities.dropna()

# Display sample data
filtered_cities
# Out:
#      City_ID                        City      Lat       Lng  Max Temp  \
# 3          3                      bethel  41.3712  -73.4140     24.20
# 57        57  san sebastian de la gomera  28.0916  -17.1133     24.20
# 93        93               alice springs -23.7000  133.8833     24.75
# 95        95                 archangelos  36.2149   28.1149     25.17
# 117      117                  dzhalagash  45.0833   64.6667     26.62
# 160      160                  greenville  35.6127  -77.3663     26.18
# 166      166                       ubari  26.5921   12.7805     25.06
# 243      243                   fruitland  38.3221  -75.6202     25.94
# 245      245                       serik  36.9169   31.0989     26.53
# 259      259           old orchard beach  43.5173  -70.3775     21.09
# 262      262                     mashhad  36.2970   59.6062     21.08
# 311      311             remire-montjoly   4.9167  -52.2667     26.02
# 317      317                    mwandiga  -4.8300   29.6581     22.04
# 324      324                   makhambet  47.6667   51.5833     24.60
# 351      351                   arvayheer  46.2639  102.7750     22.25
# 387      387                       sirte  31.2089   16.5887     25.51
# 397      397                   pinehurst  35.1954  -79.4695     26.70
# 415      415                      cortez  37.3489 -108.5859     26.13
# 416      416            sainte-catherine  46.3184  -72.5663     22.99
# 437      437                      kerben  40.2951   72.1863     23.28
# 440      440                      kigoma  -4.8769   29.6267     23.23
# 462      462                  ain sukhna  29.6002   32.3167     25.13
# 473      473                  fuengirola  36.5400   -4.6247     26.58
# 500      500                      sarnia  42.9787  -82.4041     23.96
# 518      518               fuerte olimpo -21.0415  -57.8738     24.66
# 545      545                   untsukul'  42.7115   46.7866     22.07
# 551      551                    belmonte -15.8631  -38.8828     21.79
# 565      565                     matoury   4.8483  -52.3317     25.98
# 568      568                  storm lake  42.6411  -95.2097     22.86
# 583      583                   brookings  44.3114  -96.7984     24.00
# 594      594                      tobruk  32.0836   23.9764     25.86
#
#      Humidity  Cloudiness  Wind Speed Country        Date
# 3          73           0        3.60      US  1691633047
# 57         83           0        2.06      ES  1691633053
# 93         19           0        3.60      AU  1691632498
# 95         88           0        2.99      GR  1691632808
# 117        44           0        3.03      KZ  1691633059
# 160        79           0        1.54      US  1691632801
# 166        28           0        2.94      LY  1691633065
# 243        84           0        2.57      US  1691633036
# 245        79           0        1.25      TR  1691633074
# 259        77           0        2.57      US  1691633075
# 262        56           0        2.06      IR  1691633075
# 311        89           0        2.06      GF  1691633080
# 317        57           0        0.35      TZ  1691633081
# 324        42           0        3.80      KZ  1691633082
# 351        42           0        3.01      MN  1691633084
# 387        60           0        3.48      LY  1691633088
# 397        80           0        0.00      US  1691632806
# 415        22           0        3.09      US  1691632989
# 416        90           0        1.03      CA  1691633090
# 437        29           0        1.00      KG  1691632747
# 440        58           0        0.73      TZ  1691633091
# 462        74           0        2.61      EG  1691633093
# 473        88           0        1.03      ES  1691633094
# 500        74           0        2.57      CA  1691632374
# 518        58           0        0.68      PY  1691632766
# 545        68           0        2.89      RU  1691633100
# 551        72           0        3.31      BR  1691632683
# 565        89           0        2.06      GF  1691633104
# 568        88           0        2.57      US  1691632868
# 583        78           0        2.06      US  1691632775
# 594        67           0        3.85      LY  1691632719

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = filtered_cities.copy()
hotel_df = hotel_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df
# Out:
#                            City Country      Lat       Lng  Humidity  \
# 3                        bethel      US  41.3712  -73.4140        73
# 57   san sebastian de la gomera      ES  28.0916  -17.1133        83
# 93                alice springs      AU -23.7000  133.8833        19
# 95                  archangelos      GR  36.2149   28.1149        88
# 117                  dzhalagash      KZ  45.0833   64.6667        44
# 160                  greenville      US  35.6127  -77.3663        79
# 166                       ubari      LY  26.5921   12.7805        28
# 243                   fruitland      US  38.3221  -75.6202        84
# 245                       serik      TR  36.9169   31.0989        79
# 259           old orchard beach      US  43.5173  -70.3775        77
# 262                     mashhad      IR  36.2970   59.6062        56
# 311             remire-montjoly      GF   4.9167  -52.2667        89
# 317                    mwandiga      TZ  -4.8300   29.6581        57
# 324                   makhambet      KZ  47.6667   51.5833        42
# 351                   arvayheer      MN  46.2639  102.7750        42
# 387                       sirte      LY  31.2089   16.5887        60
# 397                   pinehurst      US  35.1954  -79.4695        80
# 415                      cortez      US  37.3489 -108.5859        22
# 416            sainte-catherine      CA  46.3184  -72.5663        90
# 437                      kerben      KG  40.2951   72.1863        29
# 440                      kigoma      TZ  -4.8769   29.6267        58
# 462                  ain sukhna      EG  29.6002   32.3167        74
# 473                  fuengirola      ES  36.5400   -4.6247        88
# 500                      sarnia      CA  42.9787  -82.4041        74
# 518               fuerte olimpo      PY -21.0415  -57.8738        58
# 545                   untsukul'      RU  42.7115   46.7866        68
# 551                    belmonte      BR -15.8631  -38.8828        72
# 565                     matoury      GF   4.8483  -52.3317        89
# 568                  storm lake      US  42.6411  -95.2097        88
# 583                   brookings      US  44.3114  -96.7984        78
# 594                      tobruk      LY  32.0836   23.9764        67
#
#     Hotel Name
# 3
# 57
# 93
# 95
# 117
# 160
# 166
# 243
# 245
# 259
# 262
# 311
# 317
# 324
# 351
# 387
# 397
# 415
# 416
# 437
# 440
# 462
# 473
# 500
# 518
# 545
# 551
# 565
# 568
# 583
# 594

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel

radius = 10000
params = {
    'categories': 'accommodation.hotel',
    'apiKey': geoapify_key,
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row['Lat']
    longitude = row['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# bethel - nearest hotel: Hampton Inn Danbury
# san sebastian de la gomera - nearest hotel: Hotel Villa Gomera
# alice springs - nearest hotel: Aurora Alice Springs
# archangelos - nearest hotel: Semina
# dzhalagash - nearest hotel: No hotel found
# greenville - nearest hotel: Quality Inn
# ubari - nearest hotel: فندق اوباري
# fruitland - nearest hotel: Hampton Inn & Suites Salisbury/Fruitland
# serik - nearest hotel: Sapphire Homes
# old orchard beach - nearest hotel: Grand Victorian Hotel & Condo
# mashhad - nearest hotel: هتل تعاون
# remire-montjoly - nearest hotel: Complexe Belova
# mwandiga - nearest hotel: Mulukoyoyo Ndogo Guesthouse
# makhambet - nearest hotel: No hotel found
# arvayheer - nearest hotel: Time Hotel
# sirte - nearest hotel: فندق المدينة-سرت
# pinehurst - nearest hotel: The Magnolia Inn
# cortez - nearest hotel: BEST WESTERN Turquoise Inn & Suites
# sainte-catherine - nearest hotel: Les Suites de Laviolette
# kerben - nearest hotel: Asia
# kigoma - nearest hotel: sunset vista hotel
# ain sukhna - nearest hotel: العين السخنة
# fuengirola - nearest hotel: Hotel Casa Consistorial
# sarnia - nearest hotel: The Insignia Hotel, Sarnia, a Tribute Portfolio Hotel
# fuerte olimpo - nearest hotel: No hotel found
# untsukul' - nearest hotel: Уютный дом
# belmonte - nearest hotel: No hotel found
# matoury - nearest hotel: La Marmotte
# storm lake - nearest hotel: Super 8 Storm Lake
# brookings - nearest hotel: Quality Inn
# tobruk - nearest hotel: فندق زهرة البطنان -طبرق
#                            City Country      Lat       Lng  Humidity  \
# 3                        bethel      US  41.3712  -73.4140        73
# 57   san sebastian de la gomera      ES  28.0916  -17.1133        83
# 93                alice springs      AU -23.7000  133.8833        19
# 95                  archangelos      GR  36.2149   28.1149        88
# 117                  dzhalagash      KZ  45.0833   64.6667        44
# 160                  greenville      US  35.6127  -77.3663        79
# 166                       ubari      LY  26.5921   12.7805        28
# 243                   fruitland      US  38.3221  -75.6202        84
# 245                       serik      TR  36.9169   31.0989        79
# 259           old orchard beach      US  43.5173  -70.3775        77
# 262                     mashhad      IR  36.2970   59.6062        56
# 311             remire-montjoly      GF   4.9167  -52.2667        89
# 317                    mwandiga      TZ  -4.8300   29.6581        57
# 324                   makhambet      KZ  47.6667   51.5833        42
# 351                   arvayheer      MN  46.2639  102.7750        42
# 387                       sirte      LY  31.2089   16.5887        60
# 397                   pinehurst      US  35.1954  -79.4695        80
# 415                      cortez      US  37.3489 -108.5859        22
# 416            sainte-catherine      CA  46.3184  -72.5663        90
# 437                      kerben      KG  40.2951   72.1863        29
# 440                      kigoma      TZ  -4.8769   29.6267        58
# 462                  ain sukhna      EG  29.6002   32.3167        74
# 473                  fuengirola      ES  36.5400   -4.6247        88
# 500                      sarnia      CA  42.9787  -82.4041        74
# 518               fuerte olimpo      PY -21.0415  -57.8738        58
# 545                   untsukul'      RU  42.7115   46.7866        68
# 551                    belmonte      BR -15.8631  -38.8828        72
# 565                     matoury      GF   4.8483  -52.3317        89
# 568                  storm lake      US  42.6411  -95.2097        88
# 583                   brookings      US  44.3114  -96.7984        78
# 594                      tobruk      LY  32.0836   23.9764        67
#
#                                             Hotel Name
# 3                                  Hampton Inn Danbury
# 57                                  Hotel Villa Gomera
# 93                                Aurora Alice Springs
# 95                                              Semina
# 117                                     No hotel found
# 160                                        Quality Inn
# 166                                        فندق اوباري
# 243           Hampton Inn & Suites Salisbury/Fruitland
# 245                                     Sapphire Homes
# 259                      Grand Victorian Hotel & Condo
# 262                                          هتل تعاون
# 311                                    Complexe Belova
# 317                        Mulukoyoyo Ndogo Guesthouse
# 324                                     No hotel found
# 351                                         Time Hotel
# 387                                   فندق المدينة-سرت
# 397                                   The Magnolia Inn
# 415                BEST WESTERN Turquoise Inn & Suites
# 416                           Les Suites de Laviolette
# 437                                               Asia
# 440                                 sunset vista hotel
# 462                                       العين السخنة
# 473                            Hotel Casa Consistorial
# 500  The Insignia Hotel, Sarnia, a Tribute Portfoli...
# 518                                     No hotel found
# 545                                         Уютный дом
# 551                                     No hotel found
# 565                                        La Marmotte
# 568                                 Super 8 Storm Lake
# 583                                        Quality Inn
# 594                            فندق زهرة البطنان -طبرق

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display
# Configure the map plot
hotel_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = 'Humidity',
    hover_cols = ['City', 'Hotel Name'],
    color = 'City'
)

# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name)
