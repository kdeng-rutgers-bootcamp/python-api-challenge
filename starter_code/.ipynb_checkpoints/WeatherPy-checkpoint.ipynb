# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 639

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

url = f"{url}appid={weather_api_key}&units={units}&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(url + city).json()
        #print(city.capitalize())

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
        #print(1)

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | olovyannaya
# Processing Record 2 of Set 1 | puerto natales
# Processing Record 3 of Set 1 | margaret river
# Processing Record 4 of Set 1 | port-aux-francais
# Processing Record 5 of Set 1 | adamstown
# Processing Record 6 of Set 1 | hithadhoo
# Processing Record 7 of Set 1 | baley
# Processing Record 8 of Set 1 | wailua homesteads
# Processing Record 9 of Set 1 | hawaiian paradise park
# Processing Record 10 of Set 1 | grytviken
# Processing Record 11 of Set 1 | toyooka
# Processing Record 12 of Set 1 | minas de marcona
# Processing Record 13 of Set 1 | pisco
# Processing Record 14 of Set 1 | okhotsk
# Processing Record 15 of Set 1 | kodiak
# Processing Record 16 of Set 1 | kapa'a
# Processing Record 17 of Set 1 | bilibino
# Processing Record 18 of Set 1 | college
# Processing Record 19 of Set 1 | port mathurin
# Processing Record 20 of Set 1 | stanley
# Processing Record 21 of Set 1 | turpan
# Processing Record 22 of Set 1 | bhaisa
# Processing Record 23 of Set 1 | soure
# Processing Record 24 of Set 1 | touros
# Processing Record 25 of Set 1 | thompson
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | whitehorse
# Processing Record 28 of Set 1 | leh
# Processing Record 29 of Set 1 | usogorsk
# Processing Record 30 of Set 1 | blackmans bay
# Processing Record 31 of Set 1 | savalou
# Processing Record 32 of Set 1 | vorgashor
# Processing Record 33 of Set 1 | aq qayeh
# City not found. Skipping...
# Processing Record 34 of Set 1 | bandon
# Processing Record 35 of Set 1 | edinburgh of the seven seas
# Processing Record 36 of Set 1 | andapa
# Processing Record 37 of Set 1 | iqaluit
# Processing Record 38 of Set 1 | carnarvon
# Processing Record 39 of Set 1 | sola
# Processing Record 40 of Set 1 | ust-nera
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | west island
# Processing Record 43 of Set 1 | lebu
# Processing Record 44 of Set 1 | carbonear
# Processing Record 45 of Set 1 | marsa alam
# Processing Record 46 of Set 1 | mahibadhoo
# Processing Record 47 of Set 1 | tiksi
# Processing Record 48 of Set 1 | enewetak
# Processing Record 49 of Set 1 | waitangi
# Processing Record 50 of Set 1 | bethel
# Processing Record 0 of Set 2 | taupo
# Processing Record 1 of Set 2 | aasiaat
# Processing Record 2 of Set 2 | yuzhno-kurilsk
# Processing Record 3 of Set 2 | askino
# Processing Record 4 of Set 2 | erdenet
# Processing Record 5 of Set 2 | coxim
# Processing Record 6 of Set 2 | kingston
# Processing Record 7 of Set 2 | sitka
# Processing Record 8 of Set 2 | bardai
# Processing Record 9 of Set 2 | luderitz
# Processing Record 10 of Set 2 | trairi
# Processing Record 11 of Set 2 | qarauyl
# Processing Record 12 of Set 2 | fort mcmurray
# Processing Record 13 of Set 2 | ushuaia
# Processing Record 14 of Set 2 | magistral'nyy
# Processing Record 15 of Set 2 | olonkinbyen
# Processing Record 16 of Set 2 | lompoc
# Processing Record 17 of Set 2 | selfoss
# Processing Record 18 of Set 2 | kertih
# Processing Record 19 of Set 2 | sao jose da coroa grande
# Processing Record 20 of Set 2 | badger
# Processing Record 21 of Set 2 | ostersund
# Processing Record 22 of Set 2 | kargasok
# Processing Record 23 of Set 2 | rizokarpaso
# Processing Record 24 of Set 2 | hayma'
# City not found. Skipping...
# Processing Record 25 of Set 2 | la sarre
# Processing Record 26 of Set 2 | gadzhiyevo
# Processing Record 27 of Set 2 | ancud
# Processing Record 28 of Set 2 | port elizabeth
# Processing Record 29 of Set 2 | aleg
# Processing Record 30 of Set 2 | smithers
# Processing Record 31 of Set 2 | rio grande
# Processing Record 32 of Set 2 | stawell
# Processing Record 33 of Set 2 | cidreira
# Processing Record 34 of Set 2 | kuala terengganu
# Processing Record 35 of Set 2 | labytnangi
# Processing Record 36 of Set 2 | longyearbyen
# Processing Record 37 of Set 2 | rabaul
# Processing Record 38 of Set 2 | dunedin
# Processing Record 39 of Set 2 | yellowknife
# Processing Record 40 of Set 2 | puerto deseado
# Processing Record 41 of Set 2 | san angelo
# Processing Record 42 of Set 2 | lazaro cardenas
# Processing Record 43 of Set 2 | colon
# Processing Record 44 of Set 2 | ceerigaabo
# Processing Record 45 of Set 2 | nyurba
# Processing Record 46 of Set 2 | westport
# Processing Record 47 of Set 2 | san martin
# Processing Record 48 of Set 2 | isafjordur
# Processing Record 49 of Set 2 | fale old settlement
# Processing Record 0 of Set 3 | kalmunai
# Processing Record 1 of Set 3 | fortuna
# Processing Record 2 of Set 3 | yerofey pavlovich
# Processing Record 3 of Set 3 | iskateley
# Processing Record 4 of Set 3 | sechura
# Processing Record 5 of Set 3 | daru
# Processing Record 6 of Set 3 | kangding
# Processing Record 7 of Set 3 | nova sintra
# Processing Record 8 of Set 3 | sao gabriel da cachoeira
# Processing Record 9 of Set 3 | katabu
# Processing Record 10 of Set 3 | utrik
# Processing Record 11 of Set 3 | tindouf
# Processing Record 12 of Set 3 | qaqortoq
# Processing Record 13 of Set 3 | namibe
# Processing Record 14 of Set 3 | papatowai
# Processing Record 15 of Set 3 | chonchi
# Processing Record 16 of Set 3 | poyarkovo
# Processing Record 17 of Set 3 | hammerfest
# Processing Record 18 of Set 3 | kudahuvadhoo
# Processing Record 19 of Set 3 | satun
# Processing Record 20 of Set 3 | muzayri'
# City not found. Skipping...
# Processing Record 21 of Set 3 | luanda
# Processing Record 22 of Set 3 | trenggalek
# Processing Record 23 of Set 3 | san antonio de pale
# Processing Record 24 of Set 3 | al bayda
# Processing Record 25 of Set 3 | khovd
# Processing Record 26 of Set 3 | tazovsky
# Processing Record 27 of Set 3 | hpa-an
# Processing Record 28 of Set 3 | masterton
# Processing Record 29 of Set 3 | salobrena
# Processing Record 30 of Set 3 | langres
# Processing Record 31 of Set 3 | kovdor
# Processing Record 32 of Set 3 | udachny
# Processing Record 33 of Set 3 | fort-shevchenko
# Processing Record 34 of Set 3 | mek'ele
# Processing Record 35 of Set 3 | mabaruma
# Processing Record 36 of Set 3 | bredasdorp
# Processing Record 37 of Set 3 | saudarkrokur
# Processing Record 38 of Set 3 | lys'va
# Processing Record 39 of Set 3 | ust'-kut
# Processing Record 40 of Set 3 | vernon
# Processing Record 41 of Set 3 | christchurch
# Processing Record 42 of Set 3 | konduga
# Processing Record 43 of Set 3 | natal
# Processing Record 44 of Set 3 | peniche
# Processing Record 45 of Set 3 | atherton
# Processing Record 46 of Set 3 | invercargill
# Processing Record 47 of Set 3 | kupang
# Processing Record 48 of Set 3 | priob'ye
# Processing Record 49 of Set 3 | malango
# Processing Record 0 of Set 4 | saipan
# Processing Record 1 of Set 4 | ilulissat
# Processing Record 2 of Set 4 | guozhen
# Processing Record 3 of Set 4 | dunay
# Processing Record 4 of Set 4 | ribeira grande
# Processing Record 5 of Set 4 | zaysan
# Processing Record 6 of Set 4 | san jose village
# City not found. Skipping...
# Processing Record 7 of Set 4 | balaipungut
# Processing Record 8 of Set 4 | walvis bay
# Processing Record 9 of Set 4 | raduzhnyy
# Processing Record 10 of Set 4 | nemuro
# Processing Record 11 of Set 4 | roma
# Processing Record 12 of Set 4 | kuvandyk
# Processing Record 13 of Set 4 | bathsheba
# Processing Record 14 of Set 4 | wanning
# Processing Record 15 of Set 4 | lihue
# Processing Record 16 of Set 4 | punta arenas
# Processing Record 17 of Set 4 | pudozh
# Processing Record 18 of Set 4 | alice springs
# Processing Record 19 of Set 4 | mount gambier
# Processing Record 20 of Set 4 | macau
# Processing Record 21 of Set 4 | lembar
# City not found. Skipping...
# Processing Record 22 of Set 4 | korotchaevo
# City not found. Skipping...
# Processing Record 23 of Set 4 | puquio
# Processing Record 24 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 25 of Set 4 | le morne-rouge
# Processing Record 26 of Set 4 | laojunmiao
# Processing Record 27 of Set 4 | kapuskasing
# Processing Record 28 of Set 4 | ettrick
# Processing Record 29 of Set 4 | quixada
# Processing Record 30 of Set 4 | covington
# Processing Record 31 of Set 4 | uturoa
# Processing Record 32 of Set 4 | sinabang
# Processing Record 33 of Set 4 | dryden
# Processing Record 34 of Set 4 | cotonou
# Processing Record 35 of Set 4 | lata
# Processing Record 36 of Set 4 | erenhot
# Processing Record 37 of Set 4 | poggiardo
# Processing Record 38 of Set 4 | howrah
# Processing Record 39 of Set 4 | ingeniero jacobacci
# Processing Record 40 of Set 4 | san patricio
# Processing Record 41 of Set 4 | suai
# City not found. Skipping...
# Processing Record 42 of Set 4 | montepuez
# Processing Record 43 of Set 4 | rikaze
# Processing Record 44 of Set 4 | okha
# Processing Record 45 of Set 4 | soto la marina
# Processing Record 46 of Set 4 | orsha
# Processing Record 47 of Set 4 | guanica
# Processing Record 48 of Set 4 | ladybrand
# Processing Record 49 of Set 4 | tarariras
# Processing Record 0 of Set 5 | taroudant
# Processing Record 1 of Set 5 | sisimiut
# Processing Record 2 of Set 5 | bartlesville
# Processing Record 3 of Set 5 | guiratinga
# Processing Record 4 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 5 of Set 5 | we
# City not found. Skipping...
# Processing Record 6 of Set 5 | yilan
# Processing Record 7 of Set 5 | vallenar
# Processing Record 8 of Set 5 | mugia
# Processing Record 9 of Set 5 | afaahiti
# Processing Record 10 of Set 5 | vadso
# Processing Record 11 of Set 5 | hotan
# Processing Record 12 of Set 5 | alaghsas
# Processing Record 13 of Set 5 | tolanaro
# Processing Record 14 of Set 5 | lautoka
# Processing Record 15 of Set 5 | dongola
# Processing Record 16 of Set 5 | al ghayzah
# Processing Record 17 of Set 5 | kulattur
# Processing Record 18 of Set 5 | malvan
# Processing Record 19 of Set 5 | north bend
# Processing Record 20 of Set 5 | port macquarie
# Processing Record 21 of Set 5 | enshi
# Processing Record 22 of Set 5 | haiku-pauwela
# Processing Record 23 of Set 5 | puerto ayora
# Processing Record 24 of Set 5 | weno
# Processing Record 25 of Set 5 | siwa oasis
# Processing Record 26 of Set 5 | polyarnyy
# Processing Record 27 of Set 5 | tabas
# Processing Record 28 of Set 5 | georgetown
# Processing Record 29 of Set 5 | cumaribo
# City not found. Skipping...
# Processing Record 30 of Set 5 | altinyayla
# Processing Record 31 of Set 5 | colonia
# Processing Record 32 of Set 5 | hermanus
# Processing Record 33 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 34 of Set 5 | saint-juery
# Processing Record 35 of Set 5 | ko pha ngan
# Processing Record 36 of Set 5 | taiohae
# City not found. Skipping...
# Processing Record 37 of Set 5 | dudinka
# Processing Record 38 of Set 5 | moyale
# Processing Record 39 of Set 5 | naxos
# Processing Record 40 of Set 5 | ebon
# Processing Record 41 of Set 5 | santa maria del oro
# Processing Record 42 of Set 5 | arawa
# Processing Record 43 of Set 5 | maun
# Processing Record 44 of Set 5 | aykhal
# Processing Record 45 of Set 5 | oshkosh
# Processing Record 46 of Set 5 | mejit
# Processing Record 47 of Set 5 | hasaki
# Processing Record 48 of Set 5 | mwatate
# Processing Record 49 of Set 5 | sandnessjoen
# Processing Record 0 of Set 6 | n'zeto
# Processing Record 1 of Set 6 | banjarmasin
# Processing Record 2 of Set 6 | saurimo
# Processing Record 3 of Set 6 | acarau
# Processing Record 4 of Set 6 | kingsland
# Processing Record 5 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 6 of Set 6 | ola
# Processing Record 7 of Set 6 | syktyvkar
# Processing Record 8 of Set 6 | mil'kovo
# Processing Record 9 of Set 6 | am timan
# Processing Record 10 of Set 6 | crane
# Processing Record 11 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 12 of Set 6 | toga village
# City not found. Skipping...
# Processing Record 13 of Set 6 | porto novo
# Processing Record 14 of Set 6 | kenai
# Processing Record 15 of Set 6 | fuli
# Processing Record 16 of Set 6 | caleta de carquin
# Processing Record 17 of Set 6 | igarka
# Processing Record 18 of Set 6 | port alfred
# Processing Record 19 of Set 6 | tura
# Processing Record 20 of Set 6 | bandarbeyla
# Processing Record 21 of Set 6 | pader
# Processing Record 22 of Set 6 | saint-denis
# Processing Record 23 of Set 6 | takoradi
# Processing Record 24 of Set 6 | anadyr
# Processing Record 25 of Set 6 | tasqala
# Processing Record 26 of Set 6 | nadi
# Processing Record 27 of Set 6 | klaksvik
# Processing Record 28 of Set 6 | fruitland
# Processing Record 29 of Set 6 | harstad
# Processing Record 30 of Set 6 | barra da estiva
# Processing Record 31 of Set 6 | kolokani
# Processing Record 32 of Set 6 | new norfolk
# Processing Record 33 of Set 6 | kruisfontein
# Processing Record 34 of Set 6 | balqash
# Processing Record 35 of Set 6 | margate
# Processing Record 36 of Set 6 | dwarka
# Processing Record 37 of Set 6 | mar del plata
# Processing Record 38 of Set 6 | severo-yeniseyskiy
# Processing Record 39 of Set 6 | douglas
# Processing Record 40 of Set 6 | novyy urgal
# Processing Record 41 of Set 6 | kimbe
# Processing Record 42 of Set 6 | ingeniero guillermo n. juarez
# Processing Record 43 of Set 6 | yung shue wan
# Processing Record 44 of Set 6 | axim
# Processing Record 45 of Set 6 | port saint john's
# Processing Record 46 of Set 6 | hamilton
# Processing Record 47 of Set 6 | huinca renanco
# Processing Record 48 of Set 6 | pantai remis
# Processing Record 49 of Set 6 | paracuru
# Processing Record 0 of Set 7 | callao
# Processing Record 1 of Set 7 | abadeh
# Processing Record 2 of Set 7 | northam
# Processing Record 3 of Set 7 | acapulco de juarez
# Processing Record 4 of Set 7 | livingston
# Processing Record 5 of Set 7 | lubango
# Processing Record 6 of Set 7 | solleftea
# Processing Record 7 of Set 7 | nogliki
# Processing Record 8 of Set 7 | tromso
# Processing Record 9 of Set 7 | yeed
# Processing Record 10 of Set 7 | mana
# Processing Record 11 of Set 7 | maloye ganyushkino
# Processing Record 12 of Set 7 | rabigh
# Processing Record 13 of Set 7 | saint-pierre
# Processing Record 14 of Set 7 | tofol
# Processing Record 15 of Set 7 | atafu village
# Processing Record 16 of Set 7 | aral
# Processing Record 17 of Set 7 | arteche
# Processing Record 18 of Set 7 | port blair
# Processing Record 19 of Set 7 | fisterra
# Processing Record 20 of Set 7 | selkirk
# Processing Record 21 of Set 7 | iquique
# Processing Record 22 of Set 7 | blackwater
# Processing Record 23 of Set 7 | guerrero negro
# Processing Record 24 of Set 7 | manicore
# Processing Record 25 of Set 7 | al bawiti
# Processing Record 26 of Set 7 | arucas
# Processing Record 27 of Set 7 | talara
# Processing Record 28 of Set 7 | condom
# Processing Record 29 of Set 7 | micoud
# Processing Record 30 of Set 7 | bodaybo
# Processing Record 31 of Set 7 | san juan del sur
# Processing Record 32 of Set 7 | lang suan
# Processing Record 33 of Set 7 | xining
# Processing Record 34 of Set 7 | tash-kumyr
# Processing Record 35 of Set 7 | codrington
# Processing Record 36 of Set 7 | batangafo
# Processing Record 37 of Set 7 | la mira
# Processing Record 38 of Set 7 | ovalle
# Processing Record 39 of Set 7 | keflavik
# Processing Record 40 of Set 7 | shizunai-furukawacho
# Processing Record 41 of Set 7 | amos
# Processing Record 42 of Set 7 | uvira
# Processing Record 43 of Set 7 | coquimbo
# Processing Record 44 of Set 7 | priargunsk
# Processing Record 45 of Set 7 | port nelson
# Processing Record 46 of Set 7 | praya
# Processing Record 47 of Set 7 | labrador city
# Processing Record 48 of Set 7 | la'ie
# Processing Record 49 of Set 7 | miyako
# Processing Record 0 of Set 8 | guaduas
# Processing Record 1 of Set 8 | le muy
# Processing Record 2 of Set 8 | ambodifotatra
# Processing Record 3 of Set 8 | santana
# Processing Record 4 of Set 8 | khandyga
# Processing Record 5 of Set 8 | swan hill
# Processing Record 6 of Set 8 | mount isa
# Processing Record 7 of Set 8 | st. john's
# Processing Record 8 of Set 8 | cabo san lucas
# Processing Record 9 of Set 8 | newton
# Processing Record 10 of Set 8 | lerwick
# Processing Record 11 of Set 8 | grand baie
# Processing Record 12 of Set 8 | la passe
# Processing Record 13 of Set 8 | bonthe
# Processing Record 14 of Set 8 | dakhla
# Processing Record 15 of Set 8 | la rinconada
# Processing Record 16 of Set 8 | whitby
# Processing Record 17 of Set 8 | avarua
# Processing Record 18 of Set 8 | tsiombe
# Processing Record 19 of Set 8 | fonte boa
# Processing Record 20 of Set 8 | timbuktu
# Processing Record 21 of Set 8 | san pedro de ycuamandiyu
# Processing Record 22 of Set 8 | cantley
# Processing Record 23 of Set 8 | patnanungan
# Processing Record 24 of Set 8 | kamaishi
# Processing Record 25 of Set 8 | gizo
# Processing Record 26 of Set 8 | malanje
# Processing Record 27 of Set 8 | thinadhoo
# Processing Record 28 of Set 8 | kununurra
# Processing Record 29 of Set 8 | camacupa
# Processing Record 30 of Set 8 | cestos city
# Processing Record 31 of Set 8 | mount darwin
# Processing Record 32 of Set 8 | nar'yan-mar
# Processing Record 33 of Set 8 | tenenkou
# Processing Record 34 of Set 8 | tonder
# Processing Record 35 of Set 8 | isabela
# Processing Record 36 of Set 8 | tucurui
# Processing Record 37 of Set 8 | masallatah
# Processing Record 38 of Set 8 | bikaner
# Processing Record 39 of Set 8 | karratha
# Processing Record 40 of Set 8 | miyaly
# Processing Record 41 of Set 8 | port lincoln
# Processing Record 42 of Set 8 | barreiras
# Processing Record 43 of Set 8 | ardakan
# Processing Record 44 of Set 8 | ust-tsilma
# Processing Record 45 of Set 8 | zhanaozen
# Processing Record 46 of Set 8 | broken hill
# Processing Record 47 of Set 8 | horta
# Processing Record 48 of Set 8 | chatillon-sur-seine
# Processing Record 49 of Set 8 | chernyshevsk
# Processing Record 0 of Set 9 | meridian
# Processing Record 1 of Set 9 | quelimane
# Processing Record 2 of Set 9 | klyuchi
# Processing Record 3 of Set 9 | arraial do cabo
# Processing Record 4 of Set 9 | byron bay
# Processing Record 5 of Set 9 | corn island
# Processing Record 6 of Set 9 | massawa
# Processing Record 7 of Set 9 | bamboo flat
# Processing Record 8 of Set 9 | fada
# Processing Record 9 of Set 9 | narasannapeta
# Processing Record 10 of Set 9 | buala
# Processing Record 11 of Set 9 | fortaleza
# Processing Record 12 of Set 9 | vung tau
# Processing Record 13 of Set 9 | kingscliff
# Processing Record 14 of Set 9 | east london
# Processing Record 15 of Set 9 | carutapera
# Processing Record 16 of Set 9 | ambalavao
# Processing Record 17 of Set 9 | mili
# Processing Record 18 of Set 9 | talnakh
# Processing Record 19 of Set 9 | tayoltita
# Processing Record 20 of Set 9 | naze
# Processing Record 21 of Set 9 | dzhalagash
# Processing Record 22 of Set 9 | puerto santa
# Processing Record 23 of Set 9 | mont-tremblant
# Processing Record 24 of Set 9 | holalkere
# Processing Record 25 of Set 9 | reo
# Processing Record 26 of Set 9 | moultonborough
# Processing Record 27 of Set 9 | adrar
# Processing Record 28 of Set 9 | zouerate
# Processing Record 29 of Set 9 | san-pedro
# Processing Record 30 of Set 9 | meiktila
# Processing Record 31 of Set 9 | bibbiena
# Processing Record 32 of Set 9 | muisne
# Processing Record 33 of Set 9 | ahau
# City not found. Skipping...
# Processing Record 34 of Set 9 | mananjary
# Processing Record 35 of Set 9 | ts'alenjikha
# Processing Record 36 of Set 9 | bulandshahr
# Processing Record 37 of Set 9 | fraserburgh
# Processing Record 38 of Set 9 | suntar
# Processing Record 39 of Set 9 | sheregesh
# Processing Record 40 of Set 9 | nuuk
# Processing Record 41 of Set 9 | pimentel
# Processing Record 42 of Set 9 | tra mhor
# Processing Record 43 of Set 9 | rosignol
# Processing Record 44 of Set 9 | pozo del molle
# Processing Record 45 of Set 9 | santa terezinha
# Processing Record 46 of Set 9 | ghanzi
# Processing Record 47 of Set 9 | al qusiyah
# Processing Record 48 of Set 9 | ciudad bolivar
# Processing Record 49 of Set 9 | trinity beach
# Processing Record 0 of Set 10 | kailua-kona
# Processing Record 1 of Set 10 | sao vicente
# Processing Record 2 of Set 10 | port moresby
# Processing Record 3 of Set 10 | magdagachi
# Processing Record 4 of Set 10 | kurumul
# City not found. Skipping...
# Processing Record 5 of Set 10 | aromashevo
# Processing Record 6 of Set 10 | medinipur
# Processing Record 7 of Set 10 | bemaitso
# City not found. Skipping...
# Processing Record 8 of Set 10 | ghadamis
# Processing Record 9 of Set 10 | nuku'alofa
# Processing Record 10 of Set 10 | badou
# Processing Record 11 of Set 10 | pljevlja
# Processing Record 12 of Set 10 | casper
# Processing Record 13 of Set 10 | miquelon
# Processing Record 14 of Set 10 | antofagasta
# Processing Record 15 of Set 10 | cairns city
# City not found. Skipping...
# Processing Record 16 of Set 10 | tweed heads
# Processing Record 17 of Set 10 | tayu
# Processing Record 18 of Set 10 | lethem
# Processing Record 19 of Set 10 | beroroha
# Processing Record 20 of Set 10 | chumphon
# Processing Record 21 of Set 10 | matehuala
# Processing Record 22 of Set 10 | umm kaddadah
# Processing Record 23 of Set 10 | mariehamn
# Processing Record 24 of Set 10 | wotho
# Processing Record 25 of Set 10 | prince rupert
# Processing Record 26 of Set 10 | conceicao da barra
# Processing Record 27 of Set 10 | pokrovskoye
# Processing Record 28 of Set 10 | aswan
# Processing Record 29 of Set 10 | yangor
# City not found. Skipping...
# Processing Record 30 of Set 10 | alofi
# Processing Record 31 of Set 10 | tazacorte
# Processing Record 32 of Set 10 | tual
# Processing Record 33 of Set 10 | vredefort
# Processing Record 34 of Set 10 | katsuren-haebaru
# Processing Record 35 of Set 10 | iyo
# Processing Record 36 of Set 10 | nanao
# Processing Record 37 of Set 10 | jamaame
# Processing Record 38 of Set 10 | ha tinh
# Processing Record 39 of Set 10 | yanam
# Processing Record 40 of Set 10 | mount pearl
# Processing Record 41 of Set 10 | monifieth
# Processing Record 42 of Set 10 | tosontsengel
# Processing Record 43 of Set 10 | levuka
# Processing Record 44 of Set 10 | makokou
# Processing Record 45 of Set 10 | fort bragg
# Processing Record 46 of Set 10 | marsaskala
# City not found. Skipping...
# Processing Record 47 of Set 10 | yuxia
# Processing Record 48 of Set 10 | quiberon
# Processing Record 49 of Set 10 | kuala tungkal
# Processing Record 0 of Set 11 | cidade velha
# Processing Record 1 of Set 11 | puerto quijarro
# Processing Record 2 of Set 11 | auki
# Processing Record 3 of Set 11 | kokologo
# Processing Record 4 of Set 11 | zhytkavichy
# Processing Record 5 of Set 11 | kudat
# Processing Record 6 of Set 11 | youghal
# Processing Record 7 of Set 11 | machico
# Processing Record 8 of Set 11 | grande prairie
# Processing Record 9 of Set 11 | salinas
# Processing Record 10 of Set 11 | dabakala
# Processing Record 11 of Set 11 | pierre
# Processing Record 12 of Set 11 | maumere
# Processing Record 13 of Set 11 | tralee
# Processing Record 14 of Set 11 | macapa
# Processing Record 15 of Set 11 | brush
# Processing Record 16 of Set 11 | valdez
# Processing Record 17 of Set 11 | rongelap
# Processing Record 18 of Set 11 | princeville
# Processing Record 19 of Set 11 | kashiwazaki
# Processing Record 20 of Set 11 | kalevala
# Processing Record 21 of Set 11 | ghardaia
# Processing Record 22 of Set 11 | ningde
# Processing Record 23 of Set 11 | antonio enes
# Processing Record 24 of Set 11 | nichinan
# Processing Record 25 of Set 11 | vilyuysk
# Processing Record 26 of Set 11 | jabat
# Processing Record 27 of Set 11 | intendente alvear
# Processing Record 28 of Set 11 | presidente medici
# Processing Record 29 of Set 11 | laplace
# Processing Record 30 of Set 11 | phillip island
# Processing Record 31 of Set 11 | kamina
# Processing Record 32 of Set 11 | constantia
# Processing Record 33 of Set 11 | happy valley-goose bay
# Processing Record 34 of Set 11 | port augusta
# Processing Record 35 of Set 11 | east honolulu
# City not found. Skipping...
# Processing Record 36 of Set 11 | sao felix do xingu
# Processing Record 37 of Set 11 | yagry
# City not found. Skipping...
# Processing Record 38 of Set 11 | banda aceh
# Processing Record 39 of Set 11 | bayganin
# Processing Record 40 of Set 11 | myrina
# Processing Record 41 of Set 11 | susuman
# Processing Record 42 of Set 11 | egilsstadir
# Processing Record 43 of Set 11 | santa cruz
# Processing Record 44 of Set 11 | tismana
# Processing Record 45 of Set 11 | south cleveland
# Processing Record 46 of Set 11 | champerico
# Processing Record 47 of Set 11 | lionel town
# Processing Record 48 of Set 11 | trincomalee
# Processing Record 49 of Set 11 | zibo
# Processing Record 0 of Set 12 | sal'sk
# Processing Record 1 of Set 12 | 'ain el hadjel
# City not found. Skipping...
# Processing Record 2 of Set 12 | tuy hoa
# Processing Record 3 of Set 12 | pulandian
# Processing Record 4 of Set 12 | vilhena
# Processing Record 5 of Set 12 | tanumah
# Processing Record 6 of Set 12 | lorengau
# Processing Record 7 of Set 12 | beckley
# Processing Record 8 of Set 12 | san ignacio de velasco
# Processing Record 9 of Set 12 | berdigestyakh
# Processing Record 10 of Set 12 | balykshi
# Processing Record 11 of Set 12 | pacific grove
# Processing Record 12 of Set 12 | nelson
# Processing Record 13 of Set 12 | port-vila
# Processing Record 14 of Set 12 | lewistown
# Processing Record 15 of Set 12 | motygino
# Processing Record 16 of Set 12 | palikir - national government center
# Processing Record 17 of Set 12 | kampene
# Processing Record 18 of Set 12 | tiruchchendur
# Processing Record 19 of Set 12 | bandar lampung
# Processing Record 20 of Set 12 | grootfontein
# Processing Record 21 of Set 12 | fort wellington
# Processing Record 22 of Set 12 | corsicana
# Processing Record 23 of Set 12 | purpe
# Processing Record 24 of Set 12 | muli
# Processing Record 25 of Set 12 | mumford
# Processing Record 26 of Set 12 | el granada
# Processing Record 27 of Set 12 | kavaratti
# Processing Record 28 of Set 12 | la paz
# Processing Record 29 of Set 12 | guasdualito
# Processing Record 30 of Set 12 | maunabo
# Processing Record 31 of Set 12 | bizhbulyak
# Processing Record 32 of Set 12 | vila franca do campo
# Processing Record 33 of Set 12 | mahanoro
# Processing Record 34 of Set 12 | piechowice
# Processing Record 35 of Set 12 | brezina
# Processing Record 36 of Set 12 | olinda
# Processing Record 37 of Set 12 | rouached
# Processing Record 38 of Set 12 | ialibu
# Processing Record 39 of Set 12 | al jawf
# Processing Record 40 of Set 12 | celestun
# Processing Record 41 of Set 12 | taulaga
# Processing Record 42 of Set 12 | greymouth
# Processing Record 43 of Set 12 | midvagur
# Processing Record 44 of Set 12 | bontang
# Processing Record 45 of Set 12 | mulanje
# Processing Record 46 of Set 12 | embi
# Processing Record 47 of Set 12 | mulayjah
# Processing Record 48 of Set 12 | salinopolis
# Processing Record 49 of Set 12 | lawas
# Processing Record 0 of Set 13 | kyzylorda
# Processing Record 1 of Set 13 | nema
# Processing Record 2 of Set 13 | brookings
# Processing Record 3 of Set 13 | remire-montjoly
# Processing Record 4 of Set 13 | antsiranana
# Processing Record 5 of Set 13 | xinyuan
# Processing Record 6 of Set 13 | newnham
# Processing Record 7 of Set 13 | ad dabbah
# Processing Record 8 of Set 13 | tabora
# Processing Record 9 of Set 13 | mirny
# Processing Record 10 of Set 13 | brisas de zicatela
# Processing Record 11 of Set 13 | san juan de miraflores
# Processing Record 12 of Set 13 | salalah
# Processing Record 13 of Set 13 | yambio
# Processing Record 14 of Set 13 | kittila
# Processing Record 15 of Set 13 | nadym
# Processing Record 16 of Set 13 | papao
# Processing Record 17 of Set 13 | krasnogvardeyskoye
# Processing Record 18 of Set 13 | bardsir
# Processing Record 19 of Set 13 | at taj
# Processing Record 20 of Set 13 | morpeth
# Processing Record 21 of Set 13 | rumonge
# Processing Record 22 of Set 13 | kirensk
# Processing Record 23 of Set 13 | constitucion
# Processing Record 24 of Set 13 | morant bay
# Processing Record 25 of Set 13 | plouzane
# Processing Record 26 of Set 13 | filadelfia
# Processing Record 27 of Set 13 | puerto madryn
# Processing Record 28 of Set 13 | barra dos coqueiros
# Processing Record 29 of Set 13 | jayapura
# Processing Record 30 of Set 13 | kendari
# Processing Record 31 of Set 13 | sainte-agathe-des-monts
# Processing Record 32 of Set 13 | kavieng
# Processing Record 33 of Set 13 | chauk
# Processing Record 34 of Set 13 | pakse
# Processing Record 35 of Set 13 | damghan
# Processing Record 36 of Set 13 | chita
# Processing Record 37 of Set 13 | posse
# Processing Record 38 of Set 13 | villa yapacani
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          615
# Lat           615
# Lng           615
# Max Temp      615
# Humidity      615
# Cloudiness    615
# Wind Speed    615
# Country       615
# Date          615
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        olovyannaya  50.9500  115.5667     16.97        89         100
# 1     puerto natales -51.7236  -72.4875      2.09        94          77
# 2     margaret river -33.9500  115.0667     11.08        83         100
# 3  port-aux-francais -49.3500   70.2167      3.38        84         100
# 4          adamstown -25.0660 -130.1015     19.28        58          95
#
#    Wind Speed Country        Date
# 0        3.34      RU  1691633826
# 1        1.52      CL  1691633826
# 2        1.48      AU  1691633826
# 3       10.57      TF  1691633827
# 4        9.49      PN  1691633827

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              olovyannaya  50.9500  115.5667     16.97        89         100
# 1           puerto natales -51.7236  -72.4875      2.09        94          77
# 2           margaret river -33.9500  115.0667     11.08        83         100
# 3        port-aux-francais -49.3500   70.2167      3.38        84         100
# 4                adamstown -25.0660 -130.1015     19.28        58          95
#
#          Wind Speed Country        Date
# City_ID
# 0              3.34      RU  1691633826
# 1              1.52      CL  1691633826
# 2              1.48      AU  1691633826
# 3             10.57      TF  1691633827
# 4              9.49      PN  1691633827

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

# building linear regression model
slope, intercept, r, p, std_err = linregress(city_data_df['Lat'], city_data_df['Max Temp'])
fit = (slope * city_data_df['Lat']) + intercept

# creating scatter plot
plt.scatter(x = 'Lat', y = 'Max Temp', data = city_data_df)


# Incorporate the other graph properties
plt.plot(city_data_df['Lat'], fit, color = 'r')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')

# i decided to add the equation outside the plot so that it wouldn't overlap with the points
plt.figtext(x = 0, y = 0, s = 'y = ' + str(round(slope, 2)) + 'x + ' + str(round(intercept, 2)), c = 'r')


# Save the figure
plt.savefig("../output_data/Fig1.png")

print("The r value is:", r)
# Show plot
plt.show()
# Out:
# The r value is: 0.0004346755854641637

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity

# building linear regression model
slope, intercept, r, p, std_err = linregress(city_data_df['Lat'], city_data_df['Humidity'])
fit = (slope * city_data_df['Lat']) + intercept

# creating scatter plot
plt.scatter(x = 'Lat', y = 'Humidity', data = city_data_df)


# Incorporate the other graph properties
plt.plot(city_data_df['Lat'], fit, color = 'r')
plt.xlabel('Latitude')
plt.ylabel('Humidity')

# i decided to add the equation outside the plot so that it wouldn't overlap with the points
plt.figtext(x = 0, y = 0, s = 'y = ' + str(round(slope, 2)) + 'x + ' + str(round(intercept, 2)), c = 'r')


print("The r value is:", r)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()
# Out:
# The r value is: 0.005573906846730189

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness

# building linear regression model
slope, intercept, r, p, std_err = linregress(city_data_df['Lat'], city_data_df['Cloudiness'])
fit = (slope * city_data_df['Lat']) + intercept

# creating scatter plot
plt.scatter(x = 'Lat', y = 'Cloudiness', data = city_data_df)

# Incorporate the other graph properties

plt.plot(city_data_df['Lat'], fit, color = 'r')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

# i decided to add the equation outside the plot so that it wouldn't overlap with the points
plt.figtext(x = 0, y = 0, s = 'y = ' + str(round(slope, 2)) + 'x + ' + str(round(intercept, 2)), c = 'r')


print("The r value is:", r)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()
# Out:
# The r value is: -0.025983868127135094

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed

# building linear regression model
slope, intercept, r, p, std_err = linregress(city_data_df['Lat'], city_data_df['Wind Speed'])
fit = (slope * city_data_df['Lat']) + intercept

# creating scatter plot
plt.scatter(x = 'Lat', y = 'Wind Speed', data = city_data_df)

# Incorporate the other graph properties

plt.plot(city_data_df['Lat'], fit, color = 'r')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

# i decided to add the equation outside the plot so that it wouldn't overlap with the points
plt.figtext(x = 0, y = 0, s = 'y = ' + str(round(slope, 2)) + 'x + ' + str(round(intercept, 2)), c = 'r')


print("The r value is:", r)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()
# Out:
# The r value is: -0.1353491252061545

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lin_regress_plot(x, y, xlab, ylab, fig_name):
    slope, intercept, r, p, std_err = linregress(x, y)
    fit = (slope * x) + intercept
    plt.scatter(x = x, y = y)
    
    plt.plot(x, fit, color = 'r')
    plt.xlabel(xlab)
    plt.ylabel(ylab)
    
    # i decided to add the equation outside the plot so that it wouldn't overlap with the points
    plt.figtext(x = 0, y = 0, s = 'y = ' + str(round(slope, 2)) + 'x + ' + str(round(intercept, 2)), c = 'r')

    
    print("The r value is:", r)
    plt.savefig("../output_data/" + fig_name)
    
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                   olovyannaya  50.9500  115.5667     16.97        89
# 6                         baley  51.6000  116.6333     16.30        77
# 7             wailua homesteads  22.0669 -159.3780     31.24        75
# 8        hawaiian paradise park  19.5933 -154.9731     27.24        71
# 10                      toyooka  35.5333  134.8333     35.03        46
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        3.34      RU  1691633826
# 6               100        3.73      RU  1691633827
# 7               100        9.26      US  1691633827
# 8                40        3.60      US  1691633620
# 10               75        7.20      JP  1691633828

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1           puerto natales -51.7236  -72.4875      2.09        94          77
# 2           margaret river -33.9500  115.0667     11.08        83         100
# 3        port-aux-francais -49.3500   70.2167      3.38        84         100
# 4                adamstown -25.0660 -130.1015     19.28        58          95
# 5                hithadhoo  -0.6000   73.0833     27.10        75          77
#
#          Wind Speed Country        Date
# City_ID
# 1              1.52      CL  1691633826
# 2              1.48      AU  1691633826
# 3             10.57      TF  1691633827
# 4              9.49      PN  1691633827
# 5              2.35      MV  1691633827

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
lin_regress_plot(x = northern_hemi_df['Lat'],
                 y = northern_hemi_df['Max Temp'],
                 xlab = 'Latitude',
                 ylab = 'Max Temp',
                 fig_name = 'Fig5.png')
# Out:
# The r value is: -0.6696347944958704

# %%
# Linear regression on Southern Hemisphere
lin_regress_plot(x = southern_hemi_df['Lat'],
                 y = southern_hemi_df['Max Temp'],
                 xlab = 'Latitude',
                 ylab = 'Max Temp',
                 fig_name = 'Fig6.png')
# Out:
# The r value is: 0.7851978798676923

# %% [markdown]
# **Discussion about the linear relationship:** These outputs make sense because cities in the northern hemisphere have a lower latitude as they approach the equator, which would likely result in higher temperatures. The opposite is true for southern hemisphere cities, which is why the plots have a negative and positive correlation coefficient respectively.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_regress_plot(x = northern_hemi_df['Lat'],
                 y = northern_hemi_df['Humidity'],
                 xlab = 'Latitude',
                 ylab = 'Humidity',
                 fig_name = 'Fig7.png')
# Out:
# The r value is: -0.033505124324055405

# %%
# Southern Hemisphere
lin_regress_plot(x = southern_hemi_df['Lat'],
                 y = southern_hemi_df['Humidity'],
                 xlab = 'Latitude',
                 ylab = 'Humidity',
                 fig_name = 'Fig8.png')
# Out:
# The r value is: -0.0287184275730784

# %% [markdown]
# **Discussion about the linear relationship:** The humidity by latitude data shows less of a direct relationship between the two variables. There is a slight concentration of high-humidity data points where latitude approaches zero, though there is nothing that looks drastic enough for us to conclude anything meaningful necessarily. This may be because humidity depends on a variety of different variables that are not latitude, such as altitude or other geographical factors.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_regress_plot(x = northern_hemi_df['Lat'],
                 y = northern_hemi_df['Cloudiness'],
                 xlab = 'Latitude',
                 ylab = 'Cloudiness',
                 fig_name = 'Fig9.png')
# Out:
# The r value is: -0.14245228597711804

# %%
# Southern Hemisphere
lin_regress_plot(x = southern_hemi_df['Lat'],
                 y = southern_hemi_df['Cloudiness'],
                 xlab = 'Latitude',
                 ylab = 'Cloudiness',
                 fig_name = 'Fig10.png')
# Out:
# The r value is: -0.09905665442993139

# %% [markdown]
# **Discussion about the linear relationship:** The cloudiness measures by latitude also do not show a clearly strong correlation between variables. These results are similar to the humidity plots in that cloudiness likely depends on geographical factors other than latitude as well. Something of note is that the cities are highly concentrated in high cloudiness and low cloudiness measurements, though they don't appear to be directly affected by latitude.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_regress_plot(x = northern_hemi_df['Lat'],
                 y = northern_hemi_df['Wind Speed'],
                 xlab = 'Latitude',
                 ylab = 'Wind Speed',
                 fig_name = 'Fig11.png')
# Out:
# The r value is: -0.0908306008296117

# %%
# Southern Hemisphere
lin_regress_plot(x = southern_hemi_df['Lat'],
                 y = southern_hemi_df['Wind Speed'],
                 xlab = 'Latitude',
                 ylab = 'Wind Speed',
                 fig_name = 'Fig12.png')
# Out:
# The r value is: -0.1064769023387355

# %% [markdown]
# **Discussion about the linear relationship:** There isn't a clearly strong correlation between latitude and wind speed for the cities we've analyzed either. Wind speeds can change based on geographical features like mountains or bodies of water in the area, which our data does not account for.
